# %%
# Re-importing necessary libraries after reset
import matplotlib.pyplot as plt

# Data for elapsed time
methods = ["GPU Baseline", "Shared Memory", "Data Occupancy"]
elapsed_times = [4.24618, 3.02066,  4.25860]
# methods = ["GPU Baseline", "Padding", "Shared Memory", "2D Alignment", "Unroll"]
# elapsed_times = [1.53551, 1.46012, 1.42678, 1.35634, 1.22501]

# methods = ["GPU Baseline", "Shared Memory", "2D Alignment", "Unroll"]
# elapsed_times = [1.46012, 1.42678, 1.35634, 1.22501]

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(methods, elapsed_times, color='slategrey', width=0.6, label='Elapsed Time (s)')

# Add labels and title
# plt.xlabel('Optimization Method')
plt.ylabel('Elapsed Time (s)')
plt.title('Performance Optimization')
plt.grid(axis='y', linestyle='--', linewidth=0.5)
plt.legend()

# Annotate the bars with their values
for i, val in enumerate(elapsed_times):
    plt.text(i, val + 0.02, f'{val:.2f}', ha='center', va='bottom')

# Display the chart
plt.tight_layout()
plt.show()

# %%
# Re-importing necessary libraries after reset
import matplotlib.pyplot as plt

# Data for elapsed time
methods = ["32*32", "16*16", "8*8"]
elapsed_times = [4.36085, 3.02066,  2.89348]
# methods = ["GPU Baseline", "Padding", "Shared Memory", "2D Alignment", "Unroll"]
# elapsed_times = [1.53551, 1.46012, 1.42678, 1.35634, 1.22501]

# methods = ["GPU Baseline", "Shared Memory", "2D Alignment", "Unroll"]
# elapsed_times = [1.46012, 1.42678, 1.35634, 1.22501]

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(methods, elapsed_times, color='darkseagreen', width=0.6, label='Elapsed Time (s)')

# Add labels and title
# plt.xlabel('Optimization Method')
plt.ylabel('Elapsed Time (s)')
plt.xlabel('Block Size')

plt.title('Block Size Optimization')
plt.grid(axis='y', linestyle='--', linewidth=0.5)
plt.legend()

# Annotate the bars with their values
for i, val in enumerate(elapsed_times):
    plt.text(i, val + 0.02, f'{val:.2f}', ha='center', va='bottom')

# Display the chart
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Latency data
latency_sizes = [
    0, 1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 
    16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304
]
latency_values = [
    1.93, 2.70, 1.89, 1.87, 2.18, 2.04, 2.26, 2.05, 2.20, 3.49, 4.06, 
    4.67, 8.42, 9.57, 11.39, 15.89, 26.20, 42.28, 71.68, 140.41, 261.88, 
    511.01, 1153.02, 2328.38
]

# Bandwidth data
bandwidth_sizes = [
    1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 16384, 
    32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304
]
bandwidth_values = [
    1.48, 3.14, 6.31, 13.46, 26.75, 52.80, 102.03, 179.37, 40.23, 568.79, 
    995.54, 1524.48, 1592.28, 1862.75, 2061.50, 1696.46, 2078.95, 2026.62, 
    2118.68, 2186.90, 2164.60, 2123.73, 2005.37
]

# Plot latency
plt.figure(figsize=(10, 6))
plt.plot(latency_sizes, latency_values, marker='o')
plt.title('OSU MPI Latency Test', fontsize=14)
plt.xlabel('Message Size (Bytes)', fontsize=12)
plt.ylabel('Latency (us)', fontsize=12)
plt.xscale('log')
plt.grid(True)
plt.show()

# Plot bandwidth
plt.figure(figsize=(10, 6))
plt.plot(bandwidth_sizes, bandwidth_values, marker='o')
plt.title('OSU MPI Bandwidth Test', fontsize=14)
plt.xlabel('Message Size (Bytes)', fontsize=12)
plt.ylabel('Bandwidth (MB/s)', fontsize=12)
plt.xscale('log')
plt.grid(True)
plt.show()

# %%
# Latency data for this test
test_sizes = [
    0, 1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 4096, 8192, 
    16384, 32768, 65536, 131072, 262144, 524288, 1048576, 2097152, 4194304
]
test_latencies = [
    1.88, 1.85, 1.85, 1.81, 1.83, 1.84, 1.85, 1.96, 3.11, 3.29, 3.55, 
    4.10, 5.18, 7.34, 9.42, 12.80, 18.50, 29.95, 52.83, 94.58, 180.35, 
    353.07, 698.64, 1390.45
]

# Plotting latency for this test
plt.figure(figsize=(10, 6))
plt.plot(test_sizes, test_latencies, marker='o')
plt.title('Multi-Node OSU MPI Test', fontsize=14)
plt.xlabel('Messages Size (Bytes)', fontsize=12)
plt.ylabel('Latency(us)', fontsize=12)
plt.xscale('log')
plt.grid(True)
plt.show()
